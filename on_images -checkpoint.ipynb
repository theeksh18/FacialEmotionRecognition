# %%
import cv2

# %%
img=cv2.imread('happy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
from deepface import DeepFace

# %%
plt.imshow(img) #blue_green_red(BGR)_format

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:05<00:00,  1.46s/it]

# %%
predictions
# Out:
# {'emotion': {'angry': 0.5310712847858667,
#   'disgust': 0.004531401282292791,
#   'fear': 13.974028825759888,
#   'happy': 78.70262861251831,
#   'sad': 0.047902693040668964,
#   'surprise': 0.498611805960536,
#   'neutral': 6.241229549050331},
#  'dominant_emotion': 'happy',
#  'region': {'x': 86, 'y': 89, 'w': 158, 'h': 158},
#  'age': 30,
#  'gender': 'Woman',
#  'race': {'asian': 50.57969093322754,
#   'indian': 11.515825986862183,
#   'black': 5.072502046823502,
#   'white': 4.540742933750153,
#   'middle eastern': 2.3886999115347862,
#   'latino hispanic': 25.902539491653442},
#  'dominant_race': 'asian'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
# drawing rectangle box for face using haar cascade

# %%
faceCascade=cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#print(faceCacade.empty())
faces=faceCascade.detectMultiScale(gray,1.1,4)
#draw a rectangle around the face
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
#FOR DISPLAYING TXT IN IMAGE
cv2.putText(img,
               predictions['dominant_emotion'],
           (0,50),font,1,(0,0,255),2,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
